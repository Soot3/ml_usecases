# %% [markdown]
# #### Create Experiments

# %%
TF_EXPERIMENT_FILE = "katibheartdisease-tfjob-experiment.yaml"

# %%
import re

from IPython.utils.capture import CapturedIO


def get_resource(captured_io: CapturedIO) -> str:
    """
    Gets a resource name from `kubectl apply -f <configuration.yaml>`.

    :param str captured_io: Output captured by using `%%capture` cell magic
    :return: Name of the Kubernetes resource
    :rtype: str
    :raises Exception: if the resource could not be created
    """
    out = captured_io.stdout
    matches = re.search(r"^(.+)\s+created", out)
    if matches is not None:
        return matches.group(1)
    else:
        raise Exception(f"Cannot get resource as its creation failed: {out}. It may already exist.")

# %% [markdown]
# #### For our experiment, we want to focus on the learning rate, batch-size and optimizer. The following YAML file describes an Experiment object:

# %%
# %%writefile $TF_EXPERIMENT_FILE
# apiVersion: "kubeflow.org/v1beta1"
# kind: Experiment
# metadata:
#   namespace: ekemini
#   name: heart
# spec:
#   parallelTrialCount: 3
#   maxTrialCount: 12
#   maxFailedTrialCount: 3
#   objective:
#     type: maximize
#     goal: 0.8
#     objectiveMetricName: accuracy
#   algorithm:
#     algorithmName: random
#   metricsCollectorSpec:
#     kind: StdOut
#   parameters:
#     - name: learning_rate
#       parameterType: double
#       feasibleSpace:
#         min: "0.01"
#         max: "0.1"
#     - name: batch_size
#       parameterType: int
#       feasibleSpace:
#         min: "50"
#         max: "100"
#     - name: optimizer
#       parameterType: categorical
#       feasibleSpace:
#         list:
#           - rmsprop
#           - adam
#   trialTemplate:
#     primaryContainerName: tensorflow
#     trialParameters:
#       - name: learningRate
#         description: Learning rate for the training model
#         reference: learning_rate
#       - name: batchSize
#         description: Batch Size
#         reference: batch_size
#       - name: optimizer
#         description: Training model optimizer (sdg, adam)
#         reference: optimizer
#     trialSpec:
#       apiVersion: "kubeflow.org/v1"
#       kind: TFJob
#       spec:
#         tfReplicaSpecs:
#           Worker:
#             replicas: 1
#             restartPolicy: OnFailure
#             template:
#               metadata:
#                 annotations:
#                   sidecar.istio.io/inject: "false"
#               spec:
#                 containers:
#                   - name: tensorflow
#                     image: mavencodevv/tfjob_heart:v.0.1
#                     command:
#                       - "python"
#                       - "/tfjobheart.py"
#                       - "--batch_size=${trialParameters.batchSize}"
#                       - "--learning_rate=${trialParameters.learningRate}"
#                       - "--optimizer=${trialParameters.optimizer}"
# Out:
# Overwriting katibheartdisease-tfjob-experiment.yaml

# %% [markdown]
# #### Run and Monitor Experiments
#
# To submit our experiment, we execute:

# %%
# %%capture kubectl_output --no-stderr
! kubectl apply -f $TF_EXPERIMENT_FILE

# %% [markdown]
# #### The cell magic grabs the output of the kubectl command and stores it in an object named kubectl_output. From there we can use the utility function we defined earlier:

# %%
EXPERIMENT = get_resource(kubectl_output)

# %% [markdown]
# ##### To see the status, we can then run:

# %%
! kubectl describe $EXPERIMENT
# Out:
# Name:         heart
# Namespace:    ekemini
# Labels:       <none>
# Annotations:  <none>
# API Version:  kubeflow.org/v1beta1
# Kind:         Experiment
# Metadata:
#   Creation Timestamp:  2021-04-13T08:12:57Z
#   Finalizers:
#     update-prometheus-metrics
#   Generation:  2
#   Managed Fields:
#     API Version:  kubeflow.org/v1beta1
#     Fields Type:  FieldsV1
#     fieldsV1:
#       f:metadata:
#         f:annotations:
#           .:
#           f:kubectl.kubernetes.io/last-applied-configuration:
#       f:spec:
#         .:
#         f:algorithm:
#           .:
#           f:algorithmName:
#         f:maxFailedTrialCount:
#         f:maxTrialCount:
#         f:metricsCollectorSpec:
#         f:objective:
#           .:
#           f:goal:
#           f:objectiveMetricName:
#           f:type:
#         f:parallelTrialCount:
#         f:parameters:
#         f:trialTemplate:
#           .:
#           f:primaryContainerName:
#           f:trialParameters:
#           f:trialSpec:
#             .:
#             f:apiVersion:
#             f:kind:
#             f:spec:
#               .:
#               f:tfReplicaSpecs:
#                 .:
#                 f:Worker:
#                   .:
#                   f:replicas:
#                   f:restartPolicy:
#                   f:template:
#                     .:
#                     f:metadata:
#                       .:
#                       f:annotations:
#                         .:
#                         f:sidecar.istio.io/inject:
#                     f:spec:
#                       .:
#                       f:containers:
#     Manager:      kubectl-client-side-apply
#     Operation:    Update
#     Time:         2021-04-13T08:12:57Z
#     API Version:  kubeflow.org/v1beta1
#     Fields Type:  FieldsV1
#     fieldsV1:
#       f:metadata:
#         f:finalizers:
#       f:status:
#         .:
#         f:conditions:
#         f:currentOptimalTrial:
#           .:
#           f:bestTrialName:
#           f:observation:
#             .:
#             f:metrics:
#           f:parameterAssignments:
#         f:runningTrialList:
#         f:startTime:
#         f:trials:
#         f:trialsRunning:
#     Manager:         katib-controller
#     Operation:       Update
#     Time:            2021-04-13T08:13:16Z
#   Resource Version:  10315356
#   Self Link:         /apis/kubeflow.org/v1beta1/namespaces/ekemini/experiments/heart
#   UID:               37f657bb-e1cf-4084-9481-f004b3bc28d0
# Spec:
#   Algorithm:
#     Algorithm Name:        random
#   Max Failed Trial Count:  3
#   Max Trial Count:         12
#   Metrics Collector Spec:
#     Collector:
#       Kind:  StdOut
#   Objective:
#     Goal:  0.8
#     Metric Strategies:
#       Name:                 accuracy
#       Value:                max
#     Objective Metric Name:  accuracy
#     Type:                   maximize
#   Parallel Trial Count:     3
#   Parameters:
#     Feasible Space:
#       Max:           0.1
#       Min:           0.01
#     Name:            learning_rate
#     Parameter Type:  double
#     Feasible Space:
#       Max:           100
#       Min:           50
#     Name:            batch_size
#     Parameter Type:  int
#     Feasible Space:
#       List:
#         rmsprop
#         adam
#     Name:            optimizer
#     Parameter Type:  categorical
#   Resume Policy:     LongRunning
#   Trial Template:
#     Failure Condition:       status.conditions.#(type=="Failed")#|#(status=="True")#
#     Primary Container Name:  tensorflow
#     Primary Pod Labels:
#       Job - Role:       master
#     Success Condition:  status.conditions.#(type=="Succeeded")#|#(status=="True")#
#     Trial Parameters:
#       Description:  Learning rate for the training model
#       Name:         learningRate
#       Reference:    learning_rate
#       Description:  Batch Size
#       Name:         batchSize
#       Reference:    batch_size
#       Description:  Training model optimizer (sdg, adam)
#       Name:         optimizer
#       Reference:    optimizer
#     Trial Spec:
#       API Version:  kubeflow.org/v1
#       Kind:         TFJob
#       Spec:
#         Tf Replica Specs:
#           Worker:
#             Replicas:        1
#             Restart Policy:  OnFailure
#             Template:
#               Metadata:
#                 Annotations:
#                   sidecar.istio.io/inject:  false
#               Spec:
#                 Containers:
#                   Command:
#                     python
#                     /tfjobheart.py
#                     --batch_size=${trialParameters.batchSize}
#                     --learning_rate=${trialParameters.learningRate}
#                     --optimizer=${trialParameters.optimizer}
#                   Image:  mavencodevv/tfjob_heart:v.0.1
#                   Name:   tensorflow
# Status:
#   Conditions:
#     Last Transition Time:  2021-04-13T08:12:57Z
#     Last Update Time:      2021-04-13T08:12:57Z
#     Message:               Experiment is created
#     Reason:                ExperimentCreated
#     Status:                True
#     Type:                  Created
#     Last Transition Time:  2021-04-13T08:13:16Z
#     Last Update Time:      2021-04-13T08:13:16Z
#     Message:               Experiment is running
#     Reason:                ExperimentRunning
#     Status:                True
#     Type:                  Running
#   Current Optimal Trial:
#     Best Trial Name:
#     Observation:
#       Metrics:              <nil>
#     Parameter Assignments:  <nil>
#   Running Trial List:
#     heart-4cs6hjx5
#     heart-sc6rhzv7
#     heart-tlgzln5p
#   Start Time:      2021-04-13T08:12:57Z
#   Trials:          3
#   Trials Running:  3
# Events:            <none>

# %% [markdown]
# ##### To get the list of created experiments, use the following command:

# %%
! kubectl get experiments
# Out:
# NAME    TYPE        STATUS   AGE
# heart   Succeeded   True     48s

# %% [markdown]
# ##### To get the list of created trials, use the following command:

# %%
! kubectl get trials
# Out:
# NAME             TYPE        STATUS   AGE
# heart-4cs6hjx5   Succeeded   True     33s
# heart-sc6rhzv7   Succeeded   True     33s
# heart-tlgzln5p   Succeeded   True     33s

# %% [markdown]
# ##### After the experiment is completed, use describe to get the best trial results:

# %%
! kubectl describe $EXPERIMENT
# Out:
# Name:         heart
# Namespace:    ekemini
# Labels:       <none>
# Annotations:  <none>
# API Version:  kubeflow.org/v1beta1
# Kind:         Experiment
# Metadata:
#   Creation Timestamp:  2021-04-13T08:12:57Z
#   Finalizers:
#     update-prometheus-metrics
#   Generation:  2
#   Managed Fields:
#     API Version:  kubeflow.org/v1beta1
#     Fields Type:  FieldsV1
#     fieldsV1:
#       f:metadata:
#         f:annotations:
#           .:
#           f:kubectl.kubernetes.io/last-applied-configuration:
#       f:spec:
#         .:
#         f:algorithm:
#           .:
#           f:algorithmName:
#         f:maxFailedTrialCount:
#         f:maxTrialCount:
#         f:metricsCollectorSpec:
#         f:objective:
#           .:
#           f:goal:
#           f:objectiveMetricName:
#           f:type:
#         f:parallelTrialCount:
#         f:parameters:
#         f:trialTemplate:
#           .:
#           f:primaryContainerName:
#           f:trialParameters:
#           f:trialSpec:
#             .:
#             f:apiVersion:
#             f:kind:
#             f:spec:
#               .:
#               f:tfReplicaSpecs:
#                 .:
#                 f:Worker:
#                   .:
#                   f:replicas:
#                   f:restartPolicy:
#                   f:template:
#                     .:
#                     f:metadata:
#                       .:
#                       f:annotations:
#                         .:
#                         f:sidecar.istio.io/inject:
#                     f:spec:
#                       .:
#                       f:containers:
#     Manager:      kubectl-client-side-apply
#     Operation:    Update
#     Time:         2021-04-13T08:12:57Z
#     API Version:  kubeflow.org/v1beta1
#     Fields Type:  FieldsV1
#     fieldsV1:
#       f:metadata:
#         f:finalizers:
#       f:status:
#         .:
#         f:completionTime:
#         f:conditions:
#         f:currentOptimalTrial:
#           .:
#           f:bestTrialName:
#           f:observation:
#             .:
#             f:metrics:
#           f:parameterAssignments:
#         f:startTime:
#         f:succeededTrialList:
#         f:trials:
#         f:trialsSucceeded:
#     Manager:         katib-controller
#     Operation:       Update
#     Time:            2021-04-13T08:13:49Z
#   Resource Version:  10315891
#   Self Link:         /apis/kubeflow.org/v1beta1/namespaces/ekemini/experiments/heart
#   UID:               37f657bb-e1cf-4084-9481-f004b3bc28d0
# Spec:
#   Algorithm:
#     Algorithm Name:        random
#   Max Failed Trial Count:  3
#   Max Trial Count:         12
#   Metrics Collector Spec:
#     Collector:
#       Kind:  StdOut
#   Objective:
#     Goal:  0.8
#     Metric Strategies:
#       Name:                 accuracy
#       Value:                max
#     Objective Metric Name:  accuracy
#     Type:                   maximize
#   Parallel Trial Count:     3
#   Parameters:
#     Feasible Space:
#       Max:           0.1
#       Min:           0.01
#     Name:            learning_rate
#     Parameter Type:  double
#     Feasible Space:
#       Max:           100
#       Min:           50
#     Name:            batch_size
#     Parameter Type:  int
#     Feasible Space:
#       List:
#         rmsprop
#         adam
#     Name:            optimizer
#     Parameter Type:  categorical
#   Resume Policy:     LongRunning
#   Trial Template:
#     Failure Condition:       status.conditions.#(type=="Failed")#|#(status=="True")#
#     Primary Container Name:  tensorflow
#     Primary Pod Labels:
#       Job - Role:       master
#     Success Condition:  status.conditions.#(type=="Succeeded")#|#(status=="True")#
#     Trial Parameters:
#       Description:  Learning rate for the training model
#       Name:         learningRate
#       Reference:    learning_rate
#       Description:  Batch Size
#       Name:         batchSize
#       Reference:    batch_size
#       Description:  Training model optimizer (sdg, adam)
#       Name:         optimizer
#       Reference:    optimizer
#     Trial Spec:
#       API Version:  kubeflow.org/v1
#       Kind:         TFJob
#       Spec:
#         Tf Replica Specs:
#           Worker:
#             Replicas:        1
#             Restart Policy:  OnFailure
#             Template:
#               Metadata:
#                 Annotations:
#                   sidecar.istio.io/inject:  false
#               Spec:
#                 Containers:
#                   Command:
#                     python
#                     /tfjobheart.py
#                     --batch_size=${trialParameters.batchSize}
#                     --learning_rate=${trialParameters.learningRate}
#                     --optimizer=${trialParameters.optimizer}
#                   Image:  mavencodevv/tfjob_heart:v.0.1
#                   Name:   tensorflow
# Status:
#   Completion Time:  2021-04-13T08:13:28Z
#   Conditions:
#     Last Transition Time:  2021-04-13T08:12:57Z
#     Last Update Time:      2021-04-13T08:12:57Z
#     Message:               Experiment is created
#     Reason:                ExperimentCreated
#     Status:                True
#     Type:                  Created
#     Last Transition Time:  2021-04-13T08:13:28Z
#     Last Update Time:      2021-04-13T08:13:28Z
#     Message:               Experiment is running
#     Reason:                ExperimentRunning
#     Status:                False
#     Type:                  Running
#     Last Transition Time:  2021-04-13T08:13:28Z
#     Last Update Time:      2021-04-13T08:13:28Z
#     Message:               Experiment has succeeded because Objective goal has reached
#     Reason:                ExperimentGoalReached
#     Status:                True
#     Type:                  Succeeded
#   Current Optimal Trial:
#     Best Trial Name:  heart-sc6rhzv7
#     Observation:
#       Metrics:
#         Latest:  0.9242
#         Max:     0.9242
#         Min:     0.9242
#         Name:    accuracy
#     Parameter Assignments:
#       Name:    learning_rate
#       Value:   0.09247359714623457
#       Name:    batch_size
#       Value:   64
#       Name:    optimizer
#       Value:   rmsprop
#   Start Time:  2021-04-13T08:12:57Z
#   Succeeded Trial List:
#     heart-4cs6hjx5
#     heart-sc6rhzv7
#     heart-tlgzln5p
#   Trials:            3
#   Trials Succeeded:  3
# Events:              <none>

# %% [markdown]
# ##### Delete Katib Job Runs to Free up resources

# %%
#! kubectl delete -f $TF_EXPERIMENT_FILE

# %% [markdown]
# Check to see if the check to see if the pod is still up and running

# %%
#! kubectl -n ekemini logs -f heartdisease
